# %%
from __future__ import division
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from glob import glob
import tables as pt
import random
import math
import cv2

# %%
# Project path
cwd = os.getcwd()
data_dir = os.path.join(cwd, 'data/')

# Get images file info
image_paths = glob(data_dir + '*/*.jpg')

labels = []
classes = []
for image in image_paths:
    data_type = image.split('/')[-2]
    if data_type == 'train':
        label = ['cat', 'dog'].index((image.split('/')[-1]).split('.')[0])
        labels.append(str(label))
        classes.append(data_type)
    elif data_type == 'test':
        labels.append('-1')
        classes.append(data_type)
# create DataFrame for images info
images_df = pd.DataFrame({
        'classes': classes,
        'label': labels,
        'full_path': image_paths
    })

# %%
images_df.tail()
# Out:
#       classes                                          full_path label
# 37495   train  /Users/honghuanghui/MLClass/src/capstone/proje...     1
# 37496   train  /Users/honghuanghui/MLClass/src/capstone/proje...     1
# 37497   train  /Users/honghuanghui/MLClass/src/capstone/proje...     1
# 37498   train  /Users/honghuanghui/MLClass/src/capstone/proje...     0
# 37499   train  /Users/honghuanghui/MLClass/src/capstone/proje...     0

# %%
from random import choice
import matplotlib.patches as patches

# randomly read one image from images and get its category
def random_sample(images=image_paths):
    print("randomly read one image: ")
    im_file = choice(images)
    im_name = im_file.split('/')[-1]
    img = cv2.imread(im_file)
    fig, ax = plt.subplots()
    ax.imshow(img[..., -1::-1])
    plt.show()
    print(im_name)
    print(img.shape)
    return im_file, im_name

random_sample(image_paths)
# Out:
# randomly read one image:
# 7357.jpg
# (407, 500, 3)
# ('/Users/honghuanghui/MLClass/src/capstone/projectFile/data/test/7357.jpg',
#  '7357.jpg')

# %%
def add_shape_to_images_df(images_df = images_df):
    widths = []
    heights = []
    ratios = []
    for index, row in images_df.iterrows():
        image_path = row['full_path']
        img = cv2.imread(image_path)
        width, height, _ = img.shape
        widths.append(width)
        heights.append(height)
        ratios.append(float(width)/float(height))
        
    images_df['width'] = widths
    images_df['height'] = heights
    images_df['ratio'] = ratios

add_shape_to_images_df(images_df)

# %%
images_df.head()
# Out:
#   classes                                          full_path label  width  \
# 0    test  /Users/honghuanghui/MLClass/src/capstone/proje...    -1    375
# 1    test  /Users/honghuanghui/MLClass/src/capstone/proje...    -1    303
# 2    test  /Users/honghuanghui/MLClass/src/capstone/proje...    -1    374
# 3    test  /Users/honghuanghui/MLClass/src/capstone/proje...    -1    374
# 4    test  /Users/honghuanghui/MLClass/src/capstone/proje...    -1    250
#
#    height     ratio
# 0     499  0.751503
# 1     200  1.515000
# 2     500  0.748000
# 3     500  0.748000
# 4     349  0.716332

# %%
def plot_size_distribution():
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 2))
    ax1.plot(images_df['ratio'])
    ax1.set_title('Image size ratio')
    ax1.set_xlabel('Image index')
    ax1.set_ylabel('Ratio')
    print ('Average image ratio: ', np.mean(images_df['ratio']))
    
    ax2.plot(images_df['width'], images_df['height'], '.g')
    ax2.set_title('Image size')
    ax2.set_xlabel('Width in pixels')
    ax2.set_ylabel('Height in pixels')
    plt.show()

# %%
plot_size_distribution()
# Out:
# Average image ratio:  0.9293222499603953

# %%
images_df[(images_df['height']>500) | (images_df['width']>500) ]
# Out:
#       classes                                          full_path label  width  \
# 16509   train  /Users/honghuanghui/MLClass/src/capstone/proje...     0    768
# 17780   train  /Users/honghuanghui/MLClass/src/capstone/proje...     1    702
#
#        height     ratio
# 16509    1023  0.750733
# 17780    1050  0.668571

# %%
images_df[images_df['ratio']>3]
# Out:
#       classes                                          full_path label  width  \
# 37180   train  /Users/honghuanghui/MLClass/src/capstone/proje...     1    499
#
#        height     ratio
# 37180     153  3.261438

# %%
# Remove outliers
images_df = images_df.drop([16509, 17780, 37174]).reset_index(drop=True)

# %%
plot_size_distribution()
# Out:
# Average image ratio:  0.9293367221097265

# %%
images_df.describe()
# Out:
#               width        height         ratio
# count  37497.000000  37497.000000  37497.000000
# mean     360.274235    404.104568      0.929337
# std       96.896132    109.039656      0.275778
# min       32.000000     37.000000      0.169231
# 25%      301.000000    325.000000      0.748000
# 50%      374.000000    447.000000      0.787575
# 75%      420.000000    499.000000      1.072961
# max      500.000000    500.000000      3.261438

# %%
print('Total number of cats: {}'.format(len(images_df[images_df['label']=='0'])))
print('Total number of dogs: {}'.format(len(images_df[images_df['label']=='1'])))

print('Number of cats in training set: {}'.format(len(images_df[(images_df['label']=='0') & (images_df['classes']=='train')])))
print('Number of dogs in training set: {}'.format(len(images_df[(images_df['label']=='1') & (images_df['classes']=='train')])))
# Out:
# Total number of cats: 12498
# Total number of dogs: 12499
# Number of cats in training set: 12498
# Number of dogs in training set: 12499

# %%
images_df.to_csv("images_data.csv", index=0)
